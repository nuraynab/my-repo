# %%
import pandas as pd
import numpy as np

# Create a sample list
my_list = ['apple', 'banana', 'cherry', 'date', 'elderberry', 'fig', 'grape', 'honeydew', 'kiwi', 'lemon']

# Randomly select 5 items from the list
selected_items = np.random.choice(my_list, 5, replace=False)

# Convert to a Pandas Series for consistent output format
df = pd.Series(selected_items)
